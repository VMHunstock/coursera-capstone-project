# %%
#Coursera Capstone

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
#For this week, your main task is to decide whether you want to use the shared data or find your own dataset. In case, you choose to find your own dataset from the resources that are suggested in Week-1 video, your dataset should meet the following criteria: 

#The target or label columns should be accident "severity" in terms of human fatality, traffic delay, property damage, or any other type of accident bad impact. 
#The machine learning model should be able to predict accident "severity"
#To build a good model, the dataset should be rich and contain many observations (rows) and various attributes (columns)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
# !wget -O Data-Collisions.csv https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv
# Out:
# --2020-09-06 06:23:57--  https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv
# Resolving s3.us.cloud-object-storage.appdomain.cloud (s3.us.cloud-object-storage.appdomain.cloud)... 67.228.254.196
# Connecting to s3.us.cloud-object-storage.appdomain.cloud (s3.us.cloud-object-storage.appdomain.cloud)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73917638 (70M) [text/csv]
# Saving to: ‘Data-Collisions.csv’
#
# 100%[======================================>] 73,917,638  21.6MB/s   in 3.5s
#
# 2020-09-06 06:24:01 (20.2 MB/s) - ‘Data-Collisions.csv’ saved [73917638/73917638]

# %%
df = pd.read_csv("Data-Collisions.csv")
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %%
# summarize the data
df.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY      COLDETKEY         INTKEY  SEVERITYCODE.1  \
# count  194673.000000  194673.000000   65070.000000   194673.000000
# mean   141091.456350  141298.811381   37558.450576        1.298901
# std     86634.402737   86986.542110   51745.990273        0.457778
# min      1001.000000    1001.000000   23807.000000        1.000000
# 25%     70383.000000   70383.000000   28667.000000        1.000000
# 50%    123363.000000  123363.000000   29973.000000        1.000000
# 75%    203319.000000  203459.000000   33973.000000        2.000000
# max    331454.000000  332954.000000  757580.000000        2.000000
#
#          PERSONCOUNT       PEDCOUNT    PEDCYLCOUNT       VEHCOUNT  \
# count  194673.000000  194673.000000  194673.000000  194673.000000
# mean        2.444427       0.037139       0.028391       1.920780
# std         1.345929       0.198150       0.167413       0.631047
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000       2.000000
# 50%         2.000000       0.000000       0.000000       2.000000
# 75%         3.000000       0.000000       0.000000       2.000000
# max        81.000000       6.000000       2.000000      12.000000
#
#         SDOT_COLCODE    SDOTCOLNUM     SEGLANEKEY  CROSSWALKKEY
# count  194673.000000  1.149360e+05  194673.000000  1.946730e+05
# mean       13.867768  7.972521e+06     269.401114  9.782452e+03
# std         6.868755  2.553533e+06    3315.776055  7.226926e+04
# min         0.000000  1.007024e+06       0.000000  0.000000e+00
# 25%        11.000000  6.040015e+06       0.000000  0.000000e+00
# 50%        13.000000  8.023022e+06       0.000000  0.000000e+00
# 75%        14.000000  1.015501e+07       0.000000  0.000000e+00
# max        69.000000  1.307202e+07  525241.000000  5.239700e+06

# %%
df.shape
# Out:
# (194673, 38)

# %%
#data visualizatin and pr-processing 
df['SEVERITYCODE'].value_counts()
# Out:
# 1    136485
# 2     58188
# Name: SEVERITYCODE, dtype: int64

# %%
# notice: installing seaborn might take a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
import seaborn as sns

bins = np.linspace(df.SEVERITYCODE.min(), df.SEVERITYCODE.max(), 10)
g = sns.FacetGrid(df, col="STATUS", hue="SEVERITYCODE", palette="Set1", col_wrap=2)
g.map(plt.hist, 'ROADCOND', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#     741         else:
# --> 742             result = getattr(values, meth)(axis)
#     743
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial)
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#
# TypeError: '<=' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-095fc47bd5e3> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 bins = np.linspace(df.ROADCOND.min(), df.ROADCOND.max(), 10)
#       4 g = sns.FacetGrid(df, col="STATUS", hue="SEVERITYCODE", palette="Set1", col_wrap=2)
#       5 g.map(plt.hist, 'ROADCOND', bins=bins, ec="k")
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3624                                           'numeric_only.'.format(name))
#    3625             with np.errstate(all='ignore'):
# -> 3626                 return op(delegate, skipna=skipna, **kwds)
#    3627
#    3628         # TODO(EA) dispatch to Index
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     128             except Exception:
#     129                 try:
# --> 130                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     131                 except ValueError as e:
#     132                     # we want to transform an object array
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#     740                 result = np.nan
#     741         else:
# --> 742             result = getattr(values, meth)(axis)
#     743
#     744         result = _wrap_results(result, dtype, fill_value)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %%
bins = np.linspace(df.VEHCOUNT.min(), df.VEHCOUNT.max(), 10)
g = sns.FacetGrid(df, col="STATUS", hue="SEVERITYCODE", palette="Set1", col_wrap=2)
g.map(plt.hist, 'ROADCOND', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b5535539193c> in <module>
#       1 bins = np.linspace(df.VEHCOUNT.min(), df.VEHCOUNT.max(), 10)
#       2 g = sns.FacetGrid(df, col="STATUS", hue="SEVERITYCODE", palette="Set1", col_wrap=2)
# ----> 3 g.map(plt.hist, 'ROADCOND', bins=bins, ec="k")
#       4
#       5 g.axes[-1].legend()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     760
#     761             # Draw the plot
# --> 762             self._facet_plot(func, ax, plot_args, kwargs)
#     763
#     764         # Finalize the annotations and layout
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     844
#     845         # Draw the plot
# --> 846         func(*plot_args, **plot_kwargs)
#     847
#     848         # Sort out the supporting information
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6563                     "color kwarg must have one color per data set. %d data "
#    6564                     "sets and %d colors were provided" % (nx, len(color)))
# -> 6565                 raise ValueError(error_message)
#    6566
#    6567         # If bins are not specified either explicitly or via range,
#
# ValueError: color kwarg must have one color per data set. 132530 data sets and 1 colors were provided

# %%
#Pre-processing: Feature selection/extraction
df['PERSONCOUNT'] = df['VEHCOUNT].dt.PERSONCOUNT
bins = np.linspace(df.dayofweek.min(), df.PERSONCOUNT.max(), 10)
g = sns.FacetGrid(df, col="STATUS", hue="SEVERITYCODE", palette="Set1", col_wrap=2)
g.map(plt.hist, 'PERSONCOUNT', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()
# Out:
#   File "<ipython-input-46-57af687c8dce>", line 2
#     df['PERSONCOUNT'] = df['VEHCOUNT].dt.PERSONCOUNT
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
df['PEDCOUNT'] = df['PERSONCOUNT'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %%
#Convert Categorical features to numerical values
df.groupby(['STATUS'])['SEVERITYCODE'].value_counts(normalize=True)
# Out:
# STATUS     SEVERITYCODE
# Matched    1               0.698824
#            2               0.301176
# Unmatched  1               0.789441
#            2               0.210559
# Name: SEVERITYCODE, dtype: float64

# %%
#convert male to 0 and female to 1:
df['STATUS'].replace(to_replace=['UNMATCHED','MATCHED'], value=[0,1],inplace=True)
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %%
#one hot encoding
df.groupby(['ROADCOND'])['SEVERITYCODE'].value_counts(normalize=True)
# Out:
# ROADCOND        SEVERITYCODE
# Dry             1               0.678227
#                 2               0.321773
# Ice             1               0.774194
#                 2               0.225806
# Oil             1               0.625000
#                 2               0.375000
# Other           1               0.674242
#                 2               0.325758
# Sand/Mud/Dirt   1               0.693333
#                 2               0.306667
# Snow/Slush      1               0.833665
#                 2               0.166335
# Standing Water  1               0.739130
#                 2               0.260870
# Unknown         1               0.950325
#                 2               0.049675
# Wet             1               0.668134
#                 2               0.331866
# Name: SEVERITYCODE, dtype: float64

# %%
#feature before 0ne hot encoding 
df[['LIGHTCOND','SPEEDING', 'ADDRTYPE']].head()
# Out:
#                  LIGHTCOND SPEEDING      ADDRTYPE
# 0                 Daylight      NaN  Intersection
# 1  Dark - Street Lights On      NaN         Block
# 2                 Daylight      NaN         Block
# 3                 Daylight      NaN         Block
# 4                 Daylight      NaN  Intersection

# %%
Feature = df[['LIGHTCOND','SPEEDING']]
Feature = pd.concat([Feature,pd.get_dummies(df['ADDRTYPE'])], axis=1)
Feature.drop(['SPEEDING'], axis = 1,inplace=True)
Feature.head()
# Out:
#                  LIGHTCOND  Alley  Block  Intersection
# 0                 Daylight      0      0             1
# 1  Dark - Street Lights On      0      1             0
# 2                 Daylight      0      1             0
# 3                 Daylight      0      1             0
# 4                 Daylight      0      0             1

# %%
#define feature set X
X = Feature
X[0:5]
# Out:
#                  LIGHTCOND  Alley  Block  Intersection
# 0                 Daylight      0      0             1
# 1  Dark - Street Lights On      0      1             0
# 2                 Daylight      0      1             0
# 3                 Daylight      0      1             0
# 4                 Daylight      0      0             1

# %%
#labels
y = df['SEVERITYCODE'].values
y[0:5]
y.shape
# Out:
# (194673,)

# %%
#normalize
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-12428c5a4f6c> in <module>
#       1 #normalize
# ----> 2 X= preprocessing.StandardScaler().fit(X).transform(X)
#       3 X[0:5]
#       4 X.shape
#
# NameError: name 'preprocessing' is not defined

# %%
#KNN
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (155738, 4) (155738,)
# Test set: (38935, 4) (38935,)

# %%
from sklearn.neighbors import KNeighborsClassifier

Ks = 15
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc

plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Neighbours (K)')
plt.tight_layout()
plt.show()

print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-be4ce70f4666> in <module>
#       8
#       9     #Train Model and Predict
# ---> 10     neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
#      11     yhat=neigh.predict(X_test)
#      12     mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     889         """
#     890         if not isinstance(X, (KDTree, BallTree)):
# --> 891             X, y = check_X_y(X, y, "csr", multi_output=True)
#     892
#     893         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     565         # make sure we actually converted to numeric:
#     566         if dtype_numeric and array.dtype.kind == "O":
# --> 567             array = array.astype(np.float64)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'Daylight'
